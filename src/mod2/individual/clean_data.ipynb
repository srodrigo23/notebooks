# %%
# %pip install pandas
# %pip install numpy
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv('./salaries.csv')
df
# Out:
#        work_year experience_level employment_type                 job_title  \
# 0           2024               MI              FT            Data Scientist
# 1           2024               MI              FT            Data Scientist
# 2           2024               MI              CT            Data Scientist
# 3           2024               MI              CT            Data Scientist
# 4           2024               MI              FT      Data Science Manager
# ...          ...              ...             ...                       ...
# 16489       2020               SE              FT            Data Scientist
# 16490       2021               MI              FT  Principal Data Scientist
# 16491       2020               EN              FT            Data Scientist
# 16492       2020               EN              CT     Business Data Analyst
# 16493       2021               SE              FT      Data Science Manager
#
# ...

# %%
min_year = df['work_year'].unique().min()
max_year = df['work_year'].unique().max()
print(str(min_year) + ' - ' + str(max_year))
# Out:
# 2020 - 2024

# %%
df['experience_level'].value_counts()
# SE = 'Senior'
# MI = 'Mid-level/Intermediate'
# EN = 'Entry-level'
# EX = 'Expert/Executive'
# Out:
# experience_level
# SE    10652
# MI     4024
# EN     1319
# EX      499
# Name: count, dtype: int64

# %%
df['experience_level'].replace('SE', 'Senior', inplace=True)
df
# Out:
#        work_year experience_level employment_type                 job_title  \
# 0           2024               MI              FT            Data Scientist
# 1           2024               MI              FT            Data Scientist
# 2           2024               MI              CT            Data Scientist
# 3           2024               MI              CT            Data Scientist
# 4           2024               MI              FT      Data Science Manager
# ...          ...              ...             ...                       ...
# 16489       2020           Senior              FT            Data Scientist
# 16490       2021               MI              FT  Principal Data Scientist
# 16491       2020               EN              FT            Data Scientist
# 16492       2020               EN              CT     Business Data Analyst
# 16493       2021           Senior              FT      Data Science Manager
#
# ...
